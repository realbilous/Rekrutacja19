# %% [markdown]
# # zadanie 1

# %%
import re
import numpy as np
import pandas as pd
from PIL import Image
from os import listdir, mkdir
from os.path import join
import csv
from shutil import move

# %%
path = "images"
files = listdir(path)
n = len(files)
file_names = files
file_desc = list(map(lambda x: re.findall("(?<=stock-photo-)[\w|-]+(?=-[0-9]+\.jpg)",x)[0],files))
file_desc = list(map(lambda x: re.sub("-"," ",x),file_desc))
file_id = list(map(lambda x: re.findall("(?<=-)[0-9]+(?=.jpg)",x)[0],files))

# %%
heights = [None]*n
widths = [None]*n
mean_color = [None]*n
medians = [None]*n
brighter_row = [None]*n
brighter_col = [None]*n
for i in range(n):
    image = Image.open(join(path, files[i]))
    widths[i] = image.size[0]
    heights[i] = image.size[1]
    img_raw = np.array(image)
    mean_color[i] = '#%02x%02x%02x' % tuple(np.mean(img_raw, axis=(0,1),dtype=int))
    img_grey = image.convert('L')
    img_grey_raw = np.array(img_grey)
    medians[i] = np.median(img_grey_raw)
    max_val = np.max(img_grey_raw)
    max_coord = np.asmatrix(np.where(img_grey_raw==max_val))
    min_dist = np.Inf
    min_col = 0
    for j in range(max_coord.shape[1]):
        x = max_coord[0,j]
        y = max_coord[1,j]
        if np.sqrt(x**2+y**2) < min_dist:
            min_col=j
            min_dist = np.sqrt(x**2+y**2)
    brighter_row[i] = max_coord[0,min_col]
    brighter_col[i] = max_coord[1,min_col]

# %%
data = {'name': file_names, 
        'description': file_desc, 
        'id': file_id, 
        'width': widths , 
        'height': heights, 
        'mean color': mean_color,
       'median': medians,
       'brightest x': brighter_row,
       'brightest y': brighter_col}
data = pd.DataFrame(data)
data
# Out:
#                                                  name  \
# 0   stock-photo-lipstick-smear-smudge-swatch-isola...
# 1   stock-photo-smart-city-and-abstract-dot-point-...
# 2   stock-photo-adult-and-child-hands-holding-red-...
# 3   stock-photo-happy-family-mother-father-childre...
# 4   stock-photo-skeleton-zombie-hands-rising-out-o...
# 5   stock-photo-hurricane-dorian-in-the-carribean-...
# 6   stock-photo-zombie-rising-out-of-a-graveyard-c...
# 7   stock-photo-close-up-top-view-of-young-busines...
# 8   stock-photo-happy-dussehra-greeting-card-green...
# 9   stock-photo-architect-team-having-a-discussion...
# 10  stock-photo-october-breast-cancer-awareness-mo...
# 11  stock-photo-nature-shots-for-the-pros-15068544...
# 12  stock-photo-close-up-of-two-businessmen-shakin...
# 13  stock-photo-view-of-moon-limb-with-earth-risin...
# 14  stock-photo-top-view-of-beautiful-young-woman-...
# 15  stock-photo-suicide-prevention-and-childhood-c...
# 16  stock-photo-nice-attractive-stylish-cheerful-c...
# 17  stock-photo-young-joyful-casual-family-of-two-...
# 18  stock-photo-closeup-view-of-woman-with-drawn-f...
# 19  stock-photo-sky-background-on-sunset-nature-ab...
#
#                                           description          id  width  \
# 0   lipstick smear smudge swatch isolated on white...  1471402472   1500
# 1   smart city and abstract dot point connect with...  1499306735   1500
# 2   adult and child hands holding red heart heart ...  1487364161   1500
# 3   happy family mother father children son and da...  1438256546   1500
# 4   skeleton zombie hands rising out of a cemetery...  1495866737   1500
# 5   hurricane dorian in the carribean sea on its w...  1492317566   1500
# 6   zombie rising out of a graveyard cemetery in s...  1492357433   1500
# 7   close up top view of young business people put...  1498583432   1500
# 8        happy dussehra greeting card green leaf rice  1497972686   1500
# 9                  architect team having a discussion  1380294050   1500
# 10  october breast cancer awareness month woman in...  1505793707   1500
# 11                          nature shots for the pros  1506854450   1500
# 12  close up of two businessmen shaking hands in m...  1452180959   1500
# 13  view of moon limb with earth rising on the hor...  1454730908   1500
# 14  top view of beautiful young woman sleeping coz...  1427337869   1500
# 15  suicide prevention and childhood cancer awaren...  1482160559   1500
# 16  nice attractive stylish cheerful cheery positi...  1436812790   1500
# 17  young joyful casual family of two kids and cou...  1499295359   1500
# 18  closeup view of woman with drawn flowers on gr...  1508523470   1500
# 19  sky background on sunset nature abstract compo...  1484678003   1500
#
#     height mean color  median  brightest x  brightest y
# 0      915    #d9aaac   255.0            0            0
# 1      724    #343f53    48.0          353           18
# 2     1101    #9ca49e   194.0         1031           81
# 3     1024    #ad9979   161.0          243          422
# 4      790    #4f6168    85.0          518           74
# 5     1101    #525966    60.0          242          281
# 6     1101    #2f4051    46.0          140          248
# 7      940    #969fac   183.0           68          839
# 8     1101    #d09c21   175.0         1031           81
# 9      945    #696059    76.0          104          693
# 10     760    #bf899c   163.0          690           80
# 11    1101    #5a666d    76.0         1031           81
# 12    1101    #a1aabc   189.0          728          440
# 13    1101    #3c3d3d    46.0           39          272
# 14     945    #202c35    35.0          875           80
# 15    1101    #cfc8bd   236.0            0            4
# 16    1101    #414474    46.0         1031           81
# 17    1101    #b8a596   186.0            3           44
# 18    1101    #234838    51.0          314          977
# 19    1080    #7fa5bb   160.0         1010           80

# %%
data.to_csv("images.csv", index=False)

# %% [markdown]
# # zadanie 2

# %%
data_sorted = data.sort_values(by=['median'])
names_sorted = data_sorted.loc[:,'name']
names_sorted
# Out:
# 14    stock-photo-top-view-of-beautiful-young-woman-...
# 16    stock-photo-nice-attractive-stylish-cheerful-c...
# 6     stock-photo-zombie-rising-out-of-a-graveyard-c...
# 13    stock-photo-view-of-moon-limb-with-earth-risin...
# 1     stock-photo-smart-city-and-abstract-dot-point-...
# 18    stock-photo-closeup-view-of-woman-with-drawn-f...
# 5     stock-photo-hurricane-dorian-in-the-carribean-...
# 9     stock-photo-architect-team-having-a-discussion...
# 11    stock-photo-nature-shots-for-the-pros-15068544...
# 4     stock-photo-skeleton-zombie-hands-rising-out-o...
# 19    stock-photo-sky-background-on-sunset-nature-ab...
# 3     stock-photo-happy-family-mother-father-childre...
# 10    stock-photo-october-breast-cancer-awareness-mo...
# 8     stock-photo-happy-dussehra-greeting-card-green...
# 7     stock-photo-close-up-top-view-of-young-busines...
# 17    stock-photo-young-joyful-casual-family-of-two-...
# 12    stock-photo-close-up-of-two-businessmen-shakin...
# 2     stock-photo-adult-and-child-hands-holding-red-...
# 15    stock-photo-suicide-prevention-and-childhood-c...
# 0     stock-photo-lipstick-smear-smudge-swatch-isola...
# Name: name, dtype: object

# %%
for i in range(5):
    dir_name = "{}-images".format(i+1)
    mkdir(join(path,dir_name))
    for j in range(4):      
        move(join(path,names_sorted.iloc[i*4+j]),join(path,dir_name,names_sorted.iloc[i*4+j]))
